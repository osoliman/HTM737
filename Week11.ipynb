# %% [markdown]
# <a href="https://colab.research.google.com/github/osoliman/HTM737/blob/main/Week11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Importing the dataset**

# %% [markdown]
# **Here's a text block where I don't need to type # before commenting**

# %%
import pandas as pd

# Load ED data
df = pd.read_csv('https://www.dropbox.com/scl/fi/of5glv327d7wrgstpe8fc/df_ed.csv?rlkey=0m58ktluzuf6d439zjnv035da&dl=1')

print(f"Dataset: {df.shape[0]} rows/observations, {df.shape[1]} columns/fields")
df.head()
# Out:
# /tmp/ipython-input-4282020905.py:4: DtypeWarning: Columns (52,191,513,533,553) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('https://www.dropbox.com/scl/fi/of5glv327d7wrgstpe8fc/df_ed.csv?rlkey=0m58ktluzuf6d439zjnv035da&dl=1')
# Dataset: 24777 rows/observations, 579 columns/fields
#    VMONTH  VDAYR  ARRTIME  WAITTIME  LOV  AGE  AGER  AGEDAYS  RESIDNCE  SEX  \
# 0       1      3      647        33   58   46     4       -7         1    2
# 1       1      3     1841       109  150   56     4       -7         1    2
# 2       1      3     1333        84  198   37     3       -7         1    2
# 3       1      3     1401       159  276    7     1       -7         1    1
# 4       1      4     1947       114  248   53     4       -7         1    1
#
#    ...  RX12V3C1  RX12V3C2  RX12V3C3  RX12V3C4  SETTYPE  YEAR   CSTRATM  \
# 0  ...       NaN       NaN       NaN       NaN        3  2013  20113201
# 1  ...       NaN       NaN       NaN       NaN        3  2013  20113201
# 2  ...       NaN       NaN       NaN       NaN        3  2013  20113201
# 3  ...       NaN       NaN       NaN       NaN        3  2013  20113201
# 4  ...       NaN       NaN       NaN       NaN        3  2013  20113201
#
#     CPSUM  PATWT  EDWT
# 0  100020   2945   NaN
# 1  100020   2945   NaN
# 2  100020   2945   NaN
# 3  100020   2945   NaN
# 4  100020   2945   NaN
#
# [5 rows x 579 columns]

# %% [markdown]
# # **Creating the target variable**

# %%
# These columns indicate different types of admission
response_cols = ['ADMITHOS','TRANOTH','TRANPSYC','OBSHOS','OBSDIS']

# If ANY admission, set to 1
df['ADMITFINAL'] = (df[response_cols].sum(axis=1) >= 1).astype(int)

# Drop original columns
df = df.drop(response_cols, axis=1)

print("Admission rate:")
print(df['ADMITFINAL'].value_counts())
print(f"\n{df['ADMITFINAL'].mean():.1%} were admitted")
# Out:
# Admission rate:
# ADMITFINAL
# 0    21358
# 1     3419
# Name: count, dtype: int64
#
# 13.8% were admitted

# %%
df['ADMITFINAL'].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    1
# Name: ADMITFINAL, dtype: int64

# %% [markdown]
# # **Invalid values removal**

# %%
# See what we have
print("WAITTIME distribution:")
print(df['WAITTIME'].value_counts().head(20))
#What values are invalid here?
# Out:
# WAITTIME distribution:
# WAITTIME
# -9     3635
# -7      673
#  0      673
#  10     513
#  8      511
#  6      509
#  5      505
#  7      495
#  4      465
#  9      458
#  12     442
#  15     439
#  11     435
#  13     428
#  17     416
#  16     414
#  14     411
#  1      404
#  3      401
#  2      386
# Name: count, dtype: int64

# %%
# Fix: Replace -7 and -9 with NaN
df['WAITTIME'] = df['WAITTIME'].replace([-7, -9], None)

print("After fixing:")
print(df['WAITTIME'].describe())
print(f"\nMissing: {df['WAITTIME'].isnull().sum()}")
# Out:
# After fixing:
# count     20469
# unique      479
# top           0
# freq        673
# Name: WAITTIME, dtype: int64
#
# Missing: 4308

# %% [markdown]
# # **Missing values imputation**

# %% [markdown]
# **A- Mean imputation** (for continuous variable)

# %%
# Fill missing wait times with average
mean_wait = df['WAITTIME'].mean()
print(f"Average wait time: {mean_wait:.1f} minutes")

df['WAITTIME'] = df['WAITTIME'].fillna(mean_wait)

print(f"Missing after: {df['WAITTIME'].isnull().sum()}")

#Key functions here are ... and ...
# Out:
# Average wait time: 45.9 minutes
# Missing after: 0
# /tmp/ipython-input-1540943051.py:5: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['WAITTIME'] = df['WAITTIME'].fillna(mean_wait)

# %%
df['WAITTIME'] = df['WAITTIME'].fillna(mean_wait).infer_objects(copy=False)

# %% [markdown]
# **B- Mode imputation** (for categorical variables)
# Mode = the most repeated/common value

# %%
# Fill missing SEX with most common value
print("SEX distribution:")
print(df['SEX'].value_counts())

mode_sex = df['SEX'].mode()[0]
df['SEX'] = df['SEX'].fillna(mode_sex)
#print(mode_sex)
# Out:
# SEX distribution:
# SEX
# 1    13702
# 2    11075
# Name: count, dtype: int64

# %% [markdown]
# # **Feature Engineering**
# Create a new feature using existing data

# %%
df['WINTER'] = df['VMONTH'].isin([12, 1, 2, 3]).astype(int)

print("Winter visits:")
print(df['WINTER'].value_counts())
# Out:
# Winter visits:
# WINTER
# 0    16584
# 1     8193
# Name: count, dtype: int64

# %%
df['NIGHT'] = ((df['ARRTIME'] < 800) | (df['ARRTIME'] >= 2000)).astype(int)

print(f"{df['NIGHT'].mean():.1%} arrive at night")
# Out:
# 33.8% arrive at night

# %% [markdown]
# # **Drop unnecessary columns**

# %%
# Drop redundant time columns (we created WINTER, NIGHT)
df = df.drop(['VMONTH', 'ARRTIME', 'VDAYR'], axis=1)

# Drop identifiers
df = df.drop(['PATCODE', 'HOSPCODE'], axis=1)

# Drop AGEDAYS (we have AGE in years)
df = df.drop(['AGEDAYS'], axis=1)

print(f"Columns remaining: {df.shape[1]}")

#This could be for columns that aren't available at the time of the prediction e.g., at the start of the ER visit.
# Out:
# Columns remaining: 571

# %%
df['ADMITFINAL'].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    1
# Name: ADMITFINAL, dtype: int64

# %% [markdown]
# # **One Hot Encoding**

# %%
#search for columns with diagnosis
search_word = 'diag'
for column in df.columns:
    if search_word in column.lower():
        print(column)
# Out:
# DIAG1
# DIAG2
# DIAG3
# PRDIAG1
# PRDIAG2
# PRDIAG3
# DIAG1R
# DIAG2R
# DIAG3R
# DIAGSCRN
# TOTDIAG
# HDDIAG1
# HDDIAG2
# HDDIAG3
# HDDIAG1R
# HDDIAG2R
# HDDIAG3R

# %%
print("Before encoding:")
print(df[['DIAG1']].value_counts())
# Out:
# Before encoding:
# DIAG1
# 78900    880
# 78650    640
# 4659-    510
# 5990-    418
# 7840-    363
#         ...
# V7263      1
# V7283      1
# V7284      1
# V8289      1
# 0570-      1
# Name: count, Length: 1935, dtype: int64

# %%
df = pd.get_dummies(df, columns=['DIAG1'], prefix='DIAG1', drop_first=True)

# %%
#search for columns with diagnosis
search_word = 'diag1'
matching_columns = [column for column in df.columns if search_word in column.lower()]
#what is this from last time?
print(matching_columns)
# Out:
# ['PRDIAG1', 'DIAG1R', 'HDDIAG1', 'HDDIAG1R', 'DIAG1_0059-', 'DIAG1_0079-', 'DIAG1_00845', 'DIAG1_0085-', 'DIAG1_00863', 'DIAG1_0088-', 'DIAG1_0090-', 'DIAG1_0091-', 'DIAG1_0092-', 'DIAG1_0093-', 'DIAG1_01190', 'DIAG1_0340-', 'DIAG1_0341-', 'DIAG1_0380-', 'DIAG1_0382-', 'DIAG1_0383-', 'DIAG1_03842', 'DIAG1_0389-', 'DIAG1_04100', 'DIAG1_04110', 'DIAG1_04112', 'DIAG1_0412-', 'DIAG1_04184', 'DIAG1_04186', '
1_28262', 'DIAG1_2827-', 'DIAG1_2839-', 'DIAG1_28419', 'DIAG1_2851-', 'DIAG1_28521', 'DIAG1_28529', 'DIAG1_2859-', 'DIAG1_2866-', 'DIAG1_2869-', 'DIAG1_2870-', 'DIAG1_2875-', 'DIAG1_28800', 'DIAG1_28850', 'DIAG1_28860', 'DIAG1_2892-', 'DIAG1_2893-', 'DIAG1_2900-', 'DIAG1_29040', 'DIAG1_2910-', 'DIAG1_29181', 'DIAG1_29189', 'DIAG1_2920-', 'DIAG1_29211', 'DIAG1_29212', 'DIAG1_29289', 'DIAG1_2929-', 'DIAG1_29384', 'DIAG1_29420', 'DIAG1_29421', 'DIAG1_29530', 'DIAG1_29531', 'DIAG1_29532', 'DIAG1_29534', 'DIAG1_29570', 'DIAG1_29572', 'DIAG1_29580', 'DIAG1_29590', 'DIAG1_29604', 'DIAG1_29620', 'DIAG1_29622', 'DIAG1_29624', 'DIAG1_29630', 'DIAG1_29632', 'DIAG1_29633', 'DIAG1_29640', 'DIAG1_29641', 'DIAG1_29644', 'DIAG1_29650', 'DIAG1_29654', 'DIAG1_29656', 'DIAG1_29664', 'DIAG1_2967-', 'DIAG1_29680', 'DIAG1_29689', 'DIAG1_29690', 'DIAG1_2971-', 'DIAG1_2979-', 'DIAG1_2982-', 'DIAG1_2989-', 'DIAG1_29900', 'DIAG1_29990', 'DIAG1_30000', 'DIAG1_30001', 'DIAG1_30002', 'DIAG1_30011', 'DIAG1_30029', 'DIAG1_3003-', 'DIAG1_3004-', 'DIAG1_3009-', 'DIAG1_3013-', 'DIAG1_3019-', 'DIAG1_30300', 'DIAG1_30301', 'DIAG1_30390', 'DIAG1_30391', 'DIAG1_30392', 'DIAG1_30400', 'DIAG1_30401', 'DIAG1_30421', 'DIAG1_30430', 'DIAG1_30440', 'DIAG1_30480', 'DIAG1_30490', 'DIAG1_30500', 'DIAG1_30501', 'DIAG1_30502', 'DIAG1_3051-', 'DIAG1_30520', 'DIAG1_30530', 'DIAG1_30550', 'DIAG1_305 ...

# %%
df['DIAG1_78900'].describe()
# Out:
# count     24777
# unique        2
# top       False
# freq      23897
# Name: DIAG1_78900, dtype: object

# %% [markdown]
# # **Splitting the data into train and test**

# %%
from sklearn.model_selection import train_test_split

# Separate features from target
X = df.drop(['ADMITFINAL'], axis=1)
y = df['ADMITFINAL']

# Split: 75% train, 25% test
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

print(f"Training: {len(X_train):,} patients")
print(f"Testing: {len(X_test):,} patients")
# Out:
# Training: 18,582 patients
# Testing: 6,195 patients

# %%
X.head()
# Out:
#    WAITTIME  LOV  AGE  AGER  RESIDNCE  SEX  ETHUN  ETHIM  RACEUN  RACER  ...  \
# 0      33.0   58   46     4         1    2      1      1       1      1  ...
# 1     109.0  150   56     4         1    2      1      1       1      1  ...
# 2      84.0  198   37     3         1    2      1      1       1      1  ...
# 3     159.0  276    7     1         1    1      1      1       1      1  ...
# 4     114.0  248   53     4         1    1      1      1       1      1  ...
#
#    DIAG1_V829-  DIAG1_V8712  DIAG1_V8719  DIAG1_V872-  DIAG1_V8739  \
# 0        False        False        False        False        False
# 1        False        False        False        False        False
# 2        False        False        False        False        False
# 3        False        False        False        False        False
# 4        False        False        False        False        False
#
#    DIAG1_V990-  DIAG1_V991-  DIAG1_V992-  DIAG1_V997-  DIAG1_V998-
# 0        False        False        False        False        False
# 1        False        False        False        False        False
# 2        False        False        False        False        False
# 3        False        False        False        False        False
# 4        False        False        False        False        False
#
# [5 rows x 2503 columns]

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    1
# Name: ADMITFINAL, dtype: int64

# %%
X_train.shape
# Out:
# (18582, 2503)

# %%
X_test.shape
# Out:
# (6195, 2503)
